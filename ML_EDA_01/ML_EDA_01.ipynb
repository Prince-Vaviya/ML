# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("student_dataset_cleaned.csv")

df.head()
# Out:
#   Student_ID   Age  Gender       City  Study_Hours_per_day  \
# 0    STU2026  20.0    Male  Bangalore                  4.5
# 1    STU2054  19.0    Male  Hyderabad                  5.2
# 2    STU2049  20.0  Female     Mumbai                  3.1
# 3    STU2124  20.0  Female  Hyderabad                  2.1
# 4    STU2182  20.0    Male       Pune                  1.3
#
#    Attendance_Percentage Internet_Access Part_Time_Job  Exam_Score
# 0                   93.8             Yes            No   61.200000
# 1                  100.0              No            No   62.672414
# 2                   83.6             Yes            No   44.700000
# 3                   75.9             Yes            No   46.100000
# 4                   61.7             Yes            No   38.200000

# %%
df.shape
# Out:
# (250, 9)

# %%
df.describe()
# Out:
#               Age  Study_Hours_per_day  Attendance_Percentage  Exam_Score
# count  250.000000           250.000000             250.000000  250.000000
# mean    20.816000             4.435200              79.991739   62.672414
# std      1.898568             1.709987              10.845682   13.533935
# min     18.000000             0.500000               3.000000   25.600000
# 25%     19.000000             3.225000              74.450000   54.325000
# 50%     21.000000             4.500000              79.991739   62.672414
# 75%     22.000000             5.375000              86.975000   71.350000
# max     24.000000             9.200000             100.000000  100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Student_ID             250 non-null    object
#  1   Age                    250 non-null    float64
#  2   Gender                 250 non-null    object
#  3   City                   250 non-null    object
#  4   Study_Hours_per_day    250 non-null    float64
#  5   Attendance_Percentage  250 non-null    float64
#  6   Internet_Access        250 non-null    object
#  7   Part_Time_Job          250 non-null    object
#  8   Exam_Score             250 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 17.7+ KB

# %%
df.isnull().sum()
# Out:
# Student_ID               0
# Age                      0
# Gender                   0
# City                     0
# Study_Hours_per_day      0
# Attendance_Percentage    0
# Internet_Access          0
# Part_Time_Job            0
# Exam_Score               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[["Age", "Study_Hours_per_day",
   "Attendance_Percentage", "Exam_Score"]].boxplot(
    figsize=(10, 5)
)

plt.title("Boxplot of Numerical Columns")
plt.show()

# %%
df[df["Exam_Score"] > 100]
# Out:
# Empty DataFrame
# Columns: [Student_ID, Age, Gender, City, Study_Hours_per_day, Attendance_Percentage, Internet_Access, Part_Time_Job, Exam_Score]
# Index: []

# %%
df[df["Attendance_Percentage"] > 100]
# Out:
# Empty DataFrame
# Columns: [Student_ID, Age, Gender, City, Study_Hours_per_day, Attendance_Percentage, Internet_Access, Part_Time_Job, Exam_Score]
# Index: []

# %%
df[df["Study_Hours_per_day"] < 0]
# Out:
# Empty DataFrame
# Columns: [Student_ID, Age, Gender, City, Study_Hours_per_day, Attendance_Percentage, Internet_Access, Part_Time_Job, Exam_Score]
# Index: []

# %%
columns = [
    "Age",
    "Study_Hours_per_day",
    "Attendance_Percentage",
    "Exam_Score"
]

for col in columns:
    print("\n", col)
    print("Mean:", df[col].mean())
    print("Median:", df[col].median())
# Out:
#  Age
# Mean: 20.816
# Median: 21.0
#
#  Study_Hours_per_day
# Mean: 4.435200000000001
# Median: 4.5
#
#  Attendance_Percentage
# Mean: 79.99173913043478
# Median: 79.99173913043478
#
#  Exam_Score
# Mean: 62.67241379310345
# Median: 62.672413793103445

# %%
df["Exam_Score"].plot(kind="box")

plt.title("Exam Score Boxplot")
plt.ylabel("Exam Score")
plt.show()

# %%
df["Age"].plot(kind="hist", bins=10)

plt.title("Age Distribution")
plt.xlabel("Age")
plt.show()

# %%
df["Gender"].value_counts().plot(kind="bar")

plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Number of Students")
plt.show()

# %%
numeric_columns = [
    "Age",
    "Study_Hours_per_day",
    "Attendance_Percentage",
    "Exam_Score"
]

sns.heatmap(
    df[numeric_columns].corr(),
    annot=True
)

plt.title("Correlation Heatmap")
plt.show()
